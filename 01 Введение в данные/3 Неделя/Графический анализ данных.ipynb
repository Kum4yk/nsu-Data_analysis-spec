# %% [markdown]
# 1) Выберите верные утверждения об эмпирической функции распределения:
# - Эмпирическая функция распределения может быть построена только для признаков, измеренных номинальной шкалой
# - Эмпирическая функция распределения относится к числу инструментов графического анализа данных (+)
# - Эмпирическая функция распределения – аналог функции распределения, который мы можем построить по имеющейся у нас выборке (+)
# - Эмпирическая функция распределения работает, только если исследуемый признак распределён нормально

# %% [markdown]
# 2) В чем заключается основная идея квартета Энскомба?
# - Всегда важно графически представить данные, а не полагаться только на методы описательной статистики (+)
# - Необходимо использовать для анализа данных что-то одно: либо графики, либо описательную статистику
# - Квартет Энскомба это рок-группа из Новой Зеландии, творчество которой пропагандирует свободу распространения данных
# - Методы описательной статистики всегда более информативны, чем графическое представление данных

# %% [markdown]
# 3) В чем заключается основное ограничение анализа данных с помощью гистограмм?
# - При небольшом объеме данных гистограммы мало информативны
# - Гистограмму легко построить, но сложно интерпретировать
# - Из-за многообразия методов построения гистограмм, много времени тратится на выбор оптимального метода (+ ?)
# - Гистограмму слишком сложно построить

# %% [markdown]
# 4) Какой вывод можно сделать на основе приведенной гистограммы распределения времени ожидания?
#
# - Признак "Время ожидания" распределён нормально
# - В данных есть смесь: есть несколько групп людей, которые ждут по-разному (+)
# - Если хочется понять, чем объясняется время ожидания, то группы, которые видны в данных, хорошо бы анализировать по отдельности (+)
# - Гистограмма построена неподходящим методом, сложно делать выводы на её основе

# %% [markdown]
# 5) В чем заключается основной недостаток коробчатой диаграммы (“ящика с усами”)?
# - "Ящик с усами" не слишком информативен при небольших объемах данных
# - "Ящик с усами" не дает увидеть выбросы, находящиеся в выборке
# - "Ящик с усами" не даёт возможности увидеть смесь в данных, если она есть (+)
# - "Ящик с усами" не имеет существенных ограничений и недостатков

# %% [markdown]
# 6) Распределение количества переходов на сайт фирм, имеющих аккаунты в социальных сетях, и не имеющих таких аккаунтов, выглядит следующим образом:
#
# - Какой вывод можно сделать на основе этого графика?
# - Количество переходов на сайт никак не связано с наличием у фирмы аккаунта в социальных сетях
# - Фирмы, имеющие аккаунты в социальных сетях, получают больше переходов на сайт, чет фирмы, не имеющие аккаунтов (+)
# - Слишком много выбросов, невозможно сделать вывод на основе графика.

# %% [markdown]
# 7) Какой из инструментов визуализации данных позволяет предварительно оценить связь между двумя интервальными признаками?
# - Диаграмма рассеяния (+)
# - Гистограмма
# - Эмпирическая функция распределения
# - Коробчатая диаграмма

# %% [markdown]
# 8) Отметьте верные утверждения о диаграмме рассеяния:
#
# - С помощью диаграммы рассеяния можно увидеть разные формы распределений и найти отличия при сходных статистических характеристиках (+)
# - Построение диаграммы рассеяния позволяет предварительно оценить закономерности, связи между признаками (+)
# - Используя для анализа диаграмму рассеяния, можно выявлять внутреннюю структуру, подгруппы в данных (+)
# - Диаграмма рассеяния показывает совместное распределение признаков, но не позволяет увидеть выбросы в каждом из них
# - Диаграмма рассеяния не позволяет выявлять смеси в данных, если таковые есть

# %% [markdown]
# 9)  Укажите верные утверждения о визуализации данных:
# - Если шкалы номинальные или порядковые, то для визуализации совместных распределений можно использовать столбиковые диаграммы (+)
# - Для визуализации распределений признаков, измеренных номинальными шкалами, правомерно использовать круговые диаграммы (+)
# - Для исследования взаимосвязи номинальных и порядковых шкал можно использовать диаграмму рассеяния

# %% [markdown]
# 10) Укажите верные утверждения о визуализации данных:
# - Если одна шкала номинальная, а другая – интервальная, то хорошим вариантом отображения совместного распределения будет столбиковая диаграмма
# - Для исследования распределений порядковых признаков лучше всего использовать круговую диаграмму
# - Если одна шкала номинальная, а другая – интервальная, то хорошим вариантом отображения совместного распределения будет "ящик с усами" (+)
# - Для визуализации взаимосвязи двух интервальных признаков можно использовать диаграмму рассеяния (+)
