# %% [markdown]
# 1) Может ли случайное событие совпадать со всем пространством элементарных исходов?
#  - Да (+)
#  - Нет
#
# 2) Какое из утверждений о статистической вероятности верно?
#
# - Чем больше количество экспериментов, тем менее точно статистическая вероятность оценивает некоторую истинную вероятность события
# - Точность оценки истинной вероятности события никак не связана с количеством экспериментов
# - Чем больше количество экспериментов, тем более точно статистическая вероятность оценивает некоторую истинную вероятность события (+)
#
# 3) Укажите верные свойства вероятностей:
# - Вероятность невозможного события равна 0 (+)
# - Вероятность достоверного события равна 1 (+)
# - Вероятность разницы событий = сумме вероятностей событий
# - Если событие A является частью B, то вероятность A всегда больше вероятности B
#
#
# 4) Вероятность объединения двух событий A и B равна
# - P(A) + P(B)
# - P(A) + P(B) - P(A⋂B) (+)
# - P(A) + P(B) + P(A⋂B)
# - P(A) - P(B) - P(A⋂B)
#
# 5) Дисперсия – это:
# - Мера сходства случайных величин
# - Мера отклонения случайной величины от ее медианного значения
# - Мера отклонения случайной величины от ее математического ожидания (+)
# - Мера приближения случайной величины к ее среднему значению
#
# 6) Укажите верные свойства функции распределения:
# - P {x1≤ a<x2} = F(x1) - F(x2)
# - Если x1<x2, то F(x1) ≤ F(x2) (+)
# - -1 ≤ F(x) ≤ 1
# - P {x1≤ ξ <x2} = F(x2) - F(x1) (+)
# - Если x1<x2, то F(x1) ≥ F(x2)
# - 0 ≤ F(x) ≤ 1 (+)
#
# 7) Математическое ожидание равномерного распределения рассчитывается по формуле:
# - 1/(b-a)
# - (a+b)/2
# - (b-a)/2
#
# 8) Дисперсия равномерного распределения рассчитывается по формуле:
# - ((a+b)/2)2 - является квадратом мат.ожидания
# - (a+b)2/12
# - (b-a)2/12
# - (a+b)/2 - совпадает с мат.ожиданием
#
# 9)  Одной из характеристик нормального распределения является равенство математического ожидания коэффициенту сдвига
# - Не верно
# - Верно
#
# 10) Случайная величина А, распределенная по закону Бернулли, имеет следующие значения:
# - Успех (А=1), Неудача (А=0)
# - Успех (А=0), Неудача (А=-1)
# - Значения А могут изменяться от -∞ до + ∞
