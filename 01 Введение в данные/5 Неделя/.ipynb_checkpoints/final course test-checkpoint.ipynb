# %% [markdown]
# 1)  Из скольких элементов будет состоять пространство элементарных исходов при подбрасывании игрального кубика?
#
# - 2
# - 36
# - 6 (+)
# - Невозможно подсчитать

# %% [markdown]
# 2)  Чему равна вероятность выпадения четного числа при подбрасывании классического игрального кубика:
#
# - 1
# - ½ (+)
# - ⅓
# - ⅔

# %% [markdown]
# 3) Переход от логнормального распределения к нормальному можно осуществить:
# - Взятием логарифма случайной величины (+)
# - Взятием экспоненты случайной величины
# - Взятием интеграла случайной величины
# - Взятием в плен Джека Воробья

# %% [markdown]
# 4)  Распределение числа "успехов" в последовательности из n независимых случайных экспериментов является биномиальным, если вероятность "успеха" постоянна и равна математическому ожиданию
#
# - Не верно (+)
# - Верно

# %% [markdown]
# 5)  Имеются следующие данные по количеству лотерейных билетов, проданных за день в киосках города N:
# 79, 85, 93, 99, 112, 116, 121, 127, 138, 141, 154, 169, 173, 188, 192, 213, 256, 274, 299, 303.
#
# Сколько билетов будет продано за день с вероятностью 50%?
# - Не менее 141 (+)
# - Вероятность любого количества проданных билетов равна 50%: либо получится, либо нет
# - Не менее 154
# -
# Ровно 154

# %%
a  <- c(79, 85, 93, 99, 112, 116, 121, 127, 138, 141, 154, 169, 173, 188, 192, 213, 256, 274, 299, 303)
value = (length(a)*0.5)
print(a[value])
# Out:
# [1] 141

# %% [markdown]
# 6) Значение каких мер среднего не изменится, если мы добавим в выборку один объект с нетипично большим значением признака:
# - Медиана
# - Усеченное среднее (+)
# - Арифметическое среднее
# - Мода (+)

# %% [markdown]
# 7) Рассчитайте межквартильный размах для распределения признака (впишите получившееся число, если оно получится дробным -- впишите только целую часть):
#
# 19, 23, 28, 34, 38, 40, 45, 45, 49, 53, 56, 67, 71, 73
# - 20

# %%
a  <- c(19, 23, 28, 34, 38, 40, 45, 45, 49, 53, 56, 67, 71, 73 )
summary(a)
v = quantile(a, c(0.25, .75))
print(v["75%"] - v["25%"])
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   19.00   35.00   45.00   45.79   55.25   73.00
#   75%
# 20.25

# %% [markdown]
# 8) Какие из методов построения гистограммы наиболее информативны для отображения больших выборок?
#
# - Метод Стерджеса
# - Метод Фридмана-Диакониса
# - Метод Скотта
# - k=[√n]

# %% [markdown]
# 9) На диаграмме отображены распределения количества кликов в феврале и апреле. Какие выводы можно сделать на основе графика:
#
# - В распределении есть выбросы (+)
# - Признаки не связаны между собой
# - В данных есть смесь
# - Признаки связаны между собой (+)

# %% [markdown]
# 10) На графике изображено распределение признака “удовлетворенность жизнью” в группах людей, по-разному оценивающих свое материальное положение. Какие выводы можно сделать на основе этого графика?
#
# - Признаки скорее всего не связаны между собой
# - Признаки скорее всего связаны между собой (+)
# - Сложно делать какие-то выводы, график не информативен
# - Единицы измерения на графиках хорошо бы подписывать (+)

# %% [markdown]
# 11) Какой будет являться выборка, если есть одна или несколько характеристик, позволяющих разделить генеральную совокупность на равнозначные группы, внутри которых содержатся разнородные единицы наблюдения. Отбор внутри групп производится случайным образом.
# - Стратифицированная
# - Кластерная (+)
# - Простая случайная
# - Простая механическая

# %% [markdown]
# 12) Какие из перечисленных типов выборок обладают статистической репрезентативностью:
# - Случайная (+)
# - Кластерная (+)
# - Квотная
# - Стратифицированная (+)
# - Стихийная
# - “Снежный ком”

# %% [markdown]
# 13) Для расчета предельной ошибки выборки необходимо:
# - Определить предел функции ошибки выборки
# - Вычислить разность несмещенной дисперсии выборочной и генеральной совокупностей (+)
# - Задать вероятность расхождения средних значений выборочной и генеральной совокупности

# %% [markdown]
# 14) Как изменится объем выборки по ресторанам Москвы, если сократить предельную ошибку по среднему чеку в 10 раз (со 100 до 10 рублей)? (параметры среднего и дисперсии остались без изменений).
#
# Рассчитайте для 95% вероятности.
# - Увеличится в 11 раз
# - Уменьшится в 24,6 раза
# - Увеличится в 22 (+)
# - Уменьшится в 10 раз

# %% [markdown]
# 15) При замене пропущенных значений медианным значением:
# - Происходит смещение среднего (+)
# - Происходит удвоение минимальных значений
# - Происходит изменение медианы
# - Ничего такого не случается
